# %%
import pandas as pd

# %%
migration2017 = pd.read_excel('Excels/State_to_State_Migrations_Table_2017_clean.xls')
migration2018 = pd.read_excel('Excels/State_to_State_Migrations_Table_2018_clean.xls')
migration2019 = pd.read_excel('Excels/State_to_State_Migrations_Table_2019_clean.xls')

# %%
migration2017.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0       United States2                   321994428              275921008
# 1              Alabama                     4819343                4158224
# 2               Alaska                      730874                 595804
# 3              Arizona                     6935358                5717189
# 4             Arkansas                     2968395                2509717
#
#    Same state of residence 1 year ago    Total   Alabama   Alaska   Arizona  \
# 0                            36468599  7471493  101466.0  42972.0  163214.0
# 1                              535649   111803       NaN    424.0    1513.0
# 2                               98168    30199     942.0      NaN    1387.0
# 3                              911120   261727    1337.0   2255.0       NaN
# 4                              370309    79411     574.0    241.0    1060.0
#
# ...

# %%
migration2018.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0       United States2                   323531965              278079469
# 1              Alabama                     4832358                4173026
# 2               Alaska                      727164                 608707
# 3              Arizona                     7090137                5887700
# 4             Arkansas                     2975961                2539294
#
#    Same state of residence 1 year ago    Total  Alabama   Alaska   Arizona  \
# 0                            35921585  7571282  98194.0  39246.0  179586.0
# 1                              534914   109301      NaN    419.0    1915.0
# 2                               81229    32099    518.0      NaN     910.0
# 3                              888452   273714   2801.0   2743.0       NaN
# 4                              354774    73179    438.0    413.0     602.0
#
# ...

# %%
migration2019.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0       United States2                   324665523              280343146
# 1              Alabama                     4849509                4197698
# 2               Alaska                      722063                 609362
# 3              Arizona                     7200620                6038776
# 4             Arkansas                     2989054                2559444
#
#    Same state of residence 1 year ago    Total  Alabama   Alaska   Arizona  \
# 0                            35013848  7398337  98704.0  50134.0  173631.0
# 1                              534842   104780      NaN   1105.0     904.0
# 2                               74375    34031    260.0      NaN     886.0
# 3                              861935   253295   1750.0   1561.0       NaN
# 4                              361762    59723    636.0     98.0     692.0
#
# ...

# %%
combined = migration2017.append([migration2018, migration2019], ignore_index = False)
combined
# Out:
#    Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0        United States2                   321994428              275921008
# 1               Alabama                     4819343                4158224
# 2                Alaska                      730874                 595804
# 3               Arizona                     6935358                5717189
# 4              Arkansas                     2968395                2509717
# ..                  ...                         ...                    ...
# 48           Washington                     7527366                6253469
# 49        West Virginia                     1773280                1563611
# 50            Wisconsin                     5760481                5001140
# 51              Wyoming                      572884                 473128
# 52          Puerto Rico                     3175835                2968876
#
# ...

# %%
combined = combined.fillna(0)

# %%
combined.to_excel("combined_data.xls", index= False, header= True)
