# %%
import pandas as pd

# %%
migration2017 = pd.read_excel('Excels/State_to_State_Migrations_Table_2017.xls')
migration2018 = pd.read_excel('Excels/State_to_State_Migrations_Table_2018.xls')
migration2019 = pd.read_excel('Excels/State_to_State_Migrations_Table_2019_clean.xls')

# %%
migration2019.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0       United States2                 324665523.0            280343146.0
# 1              Alabama                   4849509.0              4197698.0
# 2               Alaska                    722063.0               609362.0
# 3              Arizona                   7200620.0              6038776.0
# 4             Arkansas                   2989054.0              2559444.0
#
#    Same state of residence 1 year ago      Total  Alabama   Alaska   Arizona  \
# 0                          35013848.0  7398337.0  98704.0  50134.0  173631.0
# 1                            534842.0   104780.0      NaN   1105.0     904.0
# 2                             74375.0    34031.0    260.0      NaN     886.0
# 3                            861935.0   253295.0   1750.0   1561.0       NaN
# 4                            361762.0    59723.0    636.0     98.0     692.0
#
# ...
