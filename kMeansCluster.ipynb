# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
training_data = pd.read_excel('new_combined_data_test.xls')
training_data.set_index('State', inplace = True)
training_data
# Out:
#                 net 2011  avg. home prices
# State
# .Alabama           13632       117503.7500
# .Alaska             8218       256963.8333
# .Arizona           65471       139398.3333
# .Arkansas          18703       104691.0833
# .California       318867       312440.0000
# ...                  ...               ...
# .Virginia          34233       292564.7273
# .Washington        91024       433595.2727
# .West Virginia    -12144       108039.9091
# .Wisconsin         15028       198568.8182
# .Wyoming            1158       254174.5455
#
# [459 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=3).fit(training_data)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[347158.82608696 219490.72661304]
#  [ 23480.09547739 190437.69108874]
#  [ 41792.78947368 473763.18898684]]

# %%
plt.scatter(training_data['net 2011'], training_data['avg. home prices'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.xlabel('Net Migration')
plt.ylabel('Average Home Price')
plt.title('Net Migration Compared to Average Home Prices \n Over the span of 10 years')
plt.show()
