# %%
import pandas as pd
from sqlalchemy import create_engine
from sql_keys import username, password

# %%
migration2010 = pd.read_excel('cleaned excels/state_to_state_migrations_table_2010_cleaned2.xls')
migration2011 = pd.read_excel('cleaned excels/state_to_state_migrations_table_2011_cleaned2.xls')
migration2012 = pd.read_excel('cleaned excels/state_to_state_migrations_table_2012_cleaned2.xls')
migration2013 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2013_clean2.xls')
migration2014 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2014_clean2.xls')
migration2015 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2015_clean2.xls')
migration2016 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2016_clean2.xls')
migration2017 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2017_clean2.xls')
migration2018 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2018_clean2.xls')
migration2019 = pd.read_excel('cleaned excels/State_to_State_Migrations_Table_2019_clean2.xls')

# %%
migration2019.head()
# Out:
#    Year Before Tax Change Current residence in  Total Population  \
# 0  2019                no              Alabama           4849509
# 1  2019                no               Alaska            722063
# 2  2019                no              Arizona           7200620
# 3  2019                no             Arkansas           2989054
# 4  2019                no           California          39084048
#
#    Same house 1 year ago  Same state of residence 1 year ago  Total_Incoming  \
# 0                4197698                              534842          104780
# 1                 609362                               74375           34031
# 2                6038776                              861935          253295
# 3                2559444                              361762           59723
# 4               34394220                             3943139          480204
#
#    Total_Outgoing  Net Migration Net Migrationpn  ...    Utah  Vermont  \
# ...

# %%
combinedyears = migration2010.append([migration2011, migration2012,migration2013, migration2014,migration2015, migration2016,migration2017, migration2018,migration2019], ignore_index = False)
combinedyears
# Out:
#     Year Before Tax Change Current residence in  Total Population  \
# 0   2010               yes              Alabama           4729509
# 1   2010               yes               Alaska            702974
# 2   2010               yes              Arizona           6332786
# 3   2010               yes             Arkansas           2888304
# 4   2010               yes           California          36907897
# ..   ...               ...                  ...               ...
# 46  2019                no             Virginia           8439982
# 47  2019                no           Washington           7527366
# 48  2019                no        West Virginia           1773280
# 49  2019                no            Wisconsin           5760481
# 50  2019                no              Wyoming            572884
#
#     Same house 1 year ago  Same state of residence 1 year ago  Total_Incoming  \
# 0                 3987155                              620465          108723
# ...

# %%
combinedyears = combinedyears.fillna(0)

# %%
combinedyears.to_excel("2010-2019combineddata.xls", index= False, header= True)

# %%
combinedyears
# Out:
#     Year Before Tax Change Current residence in  Total Population  \
# 0   2010               yes              Alabama           4729509
# 1   2010               yes               Alaska            702974
# 2   2010               yes              Arizona           6332786
# 3   2010               yes             Arkansas           2888304
# 4   2010               yes           California          36907897
# ..   ...               ...                  ...               ...
# 46  2019                no             Virginia           8439982
# 47  2019                no           Washington           7527366
# 48  2019                no        West Virginia           1773280
# 49  2019                no            Wisconsin           5760481
# 50  2019                no              Wyoming            572884
#
#     Same house 1 year ago  Same state of residence 1 year ago  Total_Incoming  \
# 0                 3987155                              620465          108723
# ...

# %%
#rds_connection_string = "postgres:bootcamp@localhost:5432/satellite"
#<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/housingdata')

# %%
engine.table_names()
# Out:
# ['housingdata']

# %%
combinedyears.to_sql(name='housingdata', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from housingdata', con=engine).head()
# Out:
#    Year Before Tax Change Current residence in  Total Population  \
# 0  2010               yes              Alabama           4729509
# 1  2010               yes               Alaska            702974
# 2  2010               yes              Arizona           6332786
# 3  2010               yes             Arkansas           2888304
# 4  2010               yes           California          36907897
#
#    Same house 1 year ago  Same state of residence 1 year ago  Total_Incoming  \
# 0                3987155                              620465          108723
# 1                 565031                               95878           36326
# 2                5069002                             1001991          222725
# 3                2387806                              412997           79127
# 4               30790221                             5413287          444749
#
#    Total_Outgoing  Net Migration Net Migrationpn  ...   Utah  Vermont  \
# ...
