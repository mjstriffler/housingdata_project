# %%
import pandas as pd

# %%
data = pd.read_excel('combined_data_1.xls')

# %%
data
# Out:
#     Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0                Alabama                     4819343                4158224
# 1                 Alaska                      730874                 595804
# 2                Arizona                     6935358                5717189
# 3               Arkansas                     2968395                2509717
# 4             California                    39085984               34009331
# ..                   ...                         ...                    ...
# 154             Virginia                     8439982                7201805
# 155           Washington                     7527366                6253469
# 156        West Virginia                     1773280                1563611
# 157            Wisconsin                     5760481                5001140
# 158              Wyoming                      572884                 473128
#
# ...
