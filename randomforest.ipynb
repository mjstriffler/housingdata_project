# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_excel("combined_data_2.xls")
df.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0              Alabama                     4819343                4158224
# 1               Alaska                      730874                 595804
# 2              Arizona                     6935358                5717189
# 3             Arkansas                     2968395                2509717
# 4           California                    39085984               34009331
#
#    Same state of residence 1 year ago  Total_Incoming  Total_Outgoing  \
# 0                              535649          111803          101466
# 1                               98168           30199           42972
# 2                              911120          261727          163214
# 3                              370309           79411           69850
# 4                             4234770          523131          661026
#
#    Net Migration  Avg. Home Price  Percent of Job Growth  Alabama  ...  \
# ...

# %%
target = df["Percent of Job Growth"]
target_names = ["negative", "positive"]

# %%
data = df.drop(["Percent of Job Growth", "Alabama", "Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","District of Columbia ",
               "Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts",
               "Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico",
               "New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island", "South Carolina",
               "South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming",
               "Total","Puerto Rico","U.S. Island Area","Foreign Country4","Foreign Country"], axis=1)
feature_names = data.columns
data.head()
# Out:
#   Current residence in  Population 1 year and over  Same house 1 year ago  \
# 0              Alabama                     4819343                4158224
# 1               Alaska                      730874                 595804
# 2              Arizona                     6935358                5717189
# 3             Arkansas                     2968395                2509717
# 4           California                    39085984               34009331
#
#    Same state of residence 1 year ago  Total_Incoming  Total_Outgoing  \
# 0                              535649          111803          101466
# 1                               98168           30199           42972
# 2                              911120          261727          163214
# 3                              370309           79411           69850
# 4                             4234770          523131          661026
#
#    Net Migration  Avg. Home Price
# 0          10337      129174.0000
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()

# %%
data.dtypes
# Out:
# Current residence in                   object
# Population 1 year and over              int64
# Same house 1 year ago                   int64
# Same state of residence 1 year ago      int64
# Total_Incoming                          int64
# Total_Outgoing                          int64
# Net Migration                           int64
# Avg. Home Price                       float64
# dtype: object

# %%
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-65c8a081b818> in <module>
# ----> 1 clf = clf.fit(X_train, y_train)
#       2 clf.score(X_test, y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
#     151             if issparse(X):
#
# ...
